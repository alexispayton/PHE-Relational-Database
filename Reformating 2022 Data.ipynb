# %%
Sys.setenv("VROOM_CONNECTION_SIZE" = 262144)

# %%
Output = '/Users/alexis/Library/CloudStorage/OneDrive-UniversityofNorthCarolinaatChapelHill/PHE Database/2. Coding/2.3. Reformatting 2022 Data/Output'
cur_date = '080725'

library(readxl)
library(tidyverse)
library(reshape2)

# reading in files
data_df = read_csv('Input/PHE_data_2022ver converted.csv')
variable_df = data.frame(read_excel("Input/PHE_county metadata_2022ver_CS.xlsx"))
# Out:
# Rows: 89 Columns: 16384
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (16384): FPS Codes, X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X12, X...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message:
# “Expecting logical in E7203 / R7203C5: got 'HIV/AIDS'”
# Warning message:
# “Expecting logical in M7203 / R7203C13: got 'per 100,000 population'”
# Warning message:
# “Expecting logical in U7203 / R7203C21: got a date”
# Warning message:
# “Expecting logical in E7204 / R7204C5: got 'HIV/AIDS'”
# Warning message:
# “Expecting logical in U7204 / R7204C21: got a date”
# Warning message:
# “Expecting logical in E7205 / R7205C5: got 'HIV/AIDS'”
# Warning message:
# “Expecting logical in M7205 / R7205C13: got 'per 100,000 population'”
# Warning message:
# “Expecting logical in U7205 / R7205C21: got a date”
# ...

# %%
head(data_df)
# Out:
#   FPS Codes X1 X2 X3 X4 X5 X6 X7 X8 X9 ⋯ X16374 X16375 X16376 X16377 X16378
# 1 39001     10 10 10 11  8  8  9 0  0  ⋯ 999999 999999 999999 999999 999999
# 2 39003     71 76 83 82 75 70 58 0  0  ⋯ 999999 999999 999999 999999 999999
# 3 39005     28 25 25 29 29 26 27 0  0  ⋯ 999999 999999 999999 999999 999999
# 4 39007     34 36 36 39 38 40 40 1  1  ⋯ 999999 999999 999999 999999 999999
# 5 39009     50 48 54 58 57 51 50 6  7  ⋯ 999999 999999 999999 999999 999999
# 6 39011     18 20 21 22 21 23 28 0  0  ⋯ 999999 999999 999999 999999 999999
#   X16379 X16380 X16381 X16382 X16383
# 1 999999 999999 999999 999999 999999
# 2 999999 999999 999999 999999 999999
# 3 999999 999999 999999 999999 999999
# 4 999999 999999 999999 999999 999999
# 5 999999 999999 999999 999999 999999
# 6 999999 999999 999999 999999 999999

# %%
head(variable_df)
# Out:
#   Domain                 Sub.Domain         Category
# 1 Health and Health Care Health Care Access Physicians
# 2 Health and Health Care Health Care Access Physicians
# 3 Health and Health Care Health Care Access Physicians
# 4 Health and Health Care Health Care Access Physicians
# 5 Health and Health Care Health Care Access Physicians
# 6 Health and Health Care Health Care Access Physicians
#   Sub.Category                    Health.Outcome Variable.ID
# 1 Phys,Primary Care, Patient Care NA             F1467516
# 2 Phys,Primary Care, Patient Care NA             F1467515
# 3 Phys,Primary Care, Patient Care NA             F1467514
# 4 Phys,Primary Care, Patient Care NA             F1467513
# 5 Phys,Primary Care, Patient Care NA             F1467512
# 6 Phys,Primary Care, Patient Care NA             F1467511
#   Variable.Name                         Sex Race Ethnicity ⋯ Data.Year
# 1 Phys,Primary Care, Patient Care, 2016 NA  NA   NA        ⋯ 2016
# ...

# %%
colnames(data_df)[2:16384] = variable_df$Variable.ID
# Out:
# Warning message in colnames(data_df)[2:16384] = variable_df$Variable.ID:
# “number of items to replace is not a multiple of replacement length”

# %%
length(unique(variable_df$Variable.Name))
length(unique(variable_df$Variable.ID))
# Out:
# [1] 40380
# [1] 81033
